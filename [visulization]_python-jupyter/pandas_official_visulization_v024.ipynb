# %%
import numpy as py
import pandas as pd

# %matplotlib inline

# %%
import matplotlib.pyplot as plt
#plt.close('all')

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))
df = df.cumsum()
df.plot();

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))
df = df.cumsum()
df.plot(kind='scatter',x='A', y='B');

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
df3['A'] = pd.Series(list(range(len(df))))
df3.plot(x='A', y='B');

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
df3['A'] = pd.Series(list(range(len(df))))
df3.plot(x='A', y='B');

# %%
# Other Plots
df.iloc[5].plot(kind='bar');

# %%
plt.figure()

df.iloc[5].plot.bar()

plt.axhline(0, color='k');

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True);

# %%
# Histgrams
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
df4.plot.hist(alpha=0.5);

# %%
df4.plot.hist(stacked=True, bins=20);

# %%
df4.plot.hist(orientation='horizontal', cumulative=True, alpha=0.5);

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.410231 -0.894768  0.577006 -0.173193
# 2000-01-02 -0.461246 -1.359271  0.803912 -0.773751
# 2000-01-03 -0.368373 -3.622561  2.019704 -0.831598
# 2000-01-04 -1.780518 -2.945253  1.516351 -0.816550
# 2000-01-05 -0.134835 -3.175682 -0.075807 -0.034835

# %%
df['A'].diff().hist()

# %%
df.diff().hist(color='k', alpha=0.5, bins=50);

# %%
data = pd.Series(np.random.randn(1000))

data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4));

# %%
#Box Plots
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box();

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot(kind='box')

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange',
         'medians': 'DarkBlue', 'caps': 'Gray'}
df.plot.box(color=color, sym='r+')

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8], sym='b*')

# %%
df = pd.DataFrame(np.random.rand(10, 5))
bp = df.boxplot()

# %%
bp = df.plot.box()

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Col1', 'Col2'])

df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])

# In [47]: plt.figure();

bp = df.boxplot(by='X')

# %%
df.head(10)
# Out:
#        Col1      Col2  X
# 0  0.656275  0.225685  A
# 1  0.699598  0.844018  A
# 2  0.510757  0.054679  A
# 3  0.809763  0.442339  A
# 4  0.360445  0.968102  A
# 5  0.869913  0.788207  B
# 6  0.733943  0.806361  B
# 7  0.273259  0.575871  B
# 8  0.807493  0.623508  B
# 9  0.077395  0.304908  B

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=['Col1', 'Col2', 'Col3'])

df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])

df['Y'] = pd.Series(['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'])

#plt.figure();

bp = df.boxplot(column=['Col1', 'Col2'], by=['X', 'Y'])

# %%
df.head()
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.860715  0.242755  0.023049  A  A
# 1  0.636958  0.917213  0.866828  A  B
# 2  0.022971  0.271158  0.703496  A  A
# 3  0.635014  0.092543  0.419890  A  B
# 4  0.404502  0.457652  0.488572  A  A

# %%
# Area Plot
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area();

# %%
df.plot.area(stacked=False)

# %%
# Scatter Plot
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b');

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');

df.plot.scatter(x='c', y='d', color='LightGreen', label='Group 2');

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');

df.plot.scatter(x='c', y='d', color='LightGreen', label='Group 2', ax=ax);

# %%
df.plot(kind='scatter', x='c', y='d', color='LightGreen', label='Group 2');

# %%
df.plot.scatter(x='a', y='b', c='c', s=50)

# %%
# You can pass other keywords supported by matplotlib scatter.
df.plot.scatter(x='a', y='b', s=df['c'] * 72, alpha=0.5);

# %%
# Hexagonal Bin Plot
# Hexbin plots can be a useful alternative to scatter plots 
# if your data are too dense to plot each point individually.
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

df['b'] = df['b'] + np.arange(1000)

df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] = df['b'] + np.arange(1000)
df['z'] = np.random.uniform(0, 3, 1000)
df.plot.hexbin(x='a', y='b', C='z', reduce_C_function=np.max, gridsize=25)

# %%
# Pie plot
# If your data includes any NaN, they will be automatically filled with 0. A ValueError will be raised 
# if there are any negative values in your data.
series = pd.Series(3 * np.random.rand(4),
                   index=['a', 'b', 'c', 'd'], name='series')
series.plot.pie(figsize=(6, 6))

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2),
                  index=['a', 'b', 'c', 'd'], columns=['x', 'y'])
df.plot.pie(subplots=True, figsize=(8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11892b9e8>,
# ...
#       dtype=object)

# %%
series.plot.pie(labels=['AA', 'BB', 'CC', 'DD'], colors=['r', 'g', 'b', 'c'],
                autopct='%.2f', fontsize=20, figsize=(6, 6))

# %%
series = pd.Series([0.1] * 4, index=['a', 'b', 'c', 'd'], name='series2')
series.plot.pie(figsize=(6, 6))

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
pd.plotting.scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde');

# %%
# Plotting Tools
# Scatter Matrix Plot
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde');

# %%
# Density Plot

ser = pd.Series(np.random.randn(1000))
ser.plot.kde()

# %%
# Andrews Curves
# Andrews curves allow one to plot multivariate data as a large number of curves 
# that are created using the attributes of samples as coefficients for Fourier series, 
# see the Wikipedia entry for more information. 
# By coloring these curves differently for each class it is possible to visualize data clustering. 
# https://en.wikipedia.org/wiki/Andrews_plot
# 此处使用sklearn库载入iris
# 如果没有请！pip自行安装
from pandas.plotting import andrews_curves
# from sklearn.datasets import load_iris
# sklearn 中的数据集没有species的，载入seaborn

import seaborn as sns
data = sns.load_dataset('iris')
data.head()

# df = pd.DataFrame(data.data, columns=data.feature_names)
# 将array转换为dataframe的说明
# sklearn的为array结构，seaborn为dataframe结构
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
andrews_curves(data, 'species')

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates(data, 'species')

# %%
# RadViz
# RadViz is a way of visualizing multi-variate data. 
# It is based on a simple spring tension minimization algorithm. 

from pandas.plotting import radviz
radviz(data, 'species');

# %%
# Lag Plot
# Lag plots are used to check if a data set or time series is random. 
# Random data should not exhibit any structure in the lag plot.
from pandas.plotting import lag_plot

spacing = np.linspace(-99 * np.pi, 99 * np.pi, num=1000)
data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(spacing))
lag_plot(data);

# %%
# Autocorrelation Plot
# Autocorrelation plots are often used for checking randomness in time series.

from pandas.plotting import autocorrelation_plot

plt.figure()
spacing = np.linspace(-9 * np.pi, 9 * np.pi, num=1000)
data = pd.Series(0.7 * np.random.rand(1000) + 0.3 * np.sin(spacing))
autocorrelation_plot(data);

# %%
# Bootstrap Plot
# Bootstrap plots are used to visually assess the uncertainty of a statistic,
# such as mean, median, midrange, etc. 
# A random subset of a specified size is selected from a data set


from pandas.plotting import bootstrap_plot
data = pd.Series(np.random.rand(1000))
bootstrap_plot(data, size=50, samples=500, color='grey');

# %%
# Plot Formatting
# matplotlib offers a range of pre-configured plotting styles. 
# Setting the style can be used to easily give plots the general look that you want. 
# Setting the style is as easy as calling matplotlib.style.use(my_plot_style) before creating your plot.

ts.plot(style='k--', label='Series');

# For each kind of plot (e.g. line, bar, scatter) 
# any additional arguments keywords are passed along to the corresponding matplotlib function 
# (ax.plot(), ax.bar(), ax.scatter()). 
# These can be used to control additional styling, beyond what pandas provides.

# %%
# Controlling the Legend

df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))
df = df.cumsum()
df.plot(legend=False);

# %%
# Scales
# You may pass logy to get a log-scale Y axis.

ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))
ts = np.exp(ts.cumsum())
ts.plot(logy=True);

# %%
# Plotting on a Secondary Y-axis
df.A.plot()
df.B.plot(secondary_y=True, style='g');

# %%
# To plot some columns in a DataFrame, 
# give the column names to the secondary_y keyword:

ax = df.plot(secondary_y=['A', 'B']);
# out Text(0, 0.5, 'CD scale')
ax.right_ax.set_ylabel('AB scale');
# out Text(0, 0.5, 'AB scale')

# %%
# Note that the columns plotted on the secondary y-axis 
# is automatically marked with “(right)” in the legend. 
# To turn off the automatic marking, 
# use the mark_right=False keyword:
df.plot(secondary_y=['A', 'B'], mark_right=False);

# %%
# Suppressing Tick Resolution Adjustment
# pandas includes automatic tick resolution adjustment for regular frequency time-series data. 

df.A.plot();

# %%
df.A.plot(x_compat=True);

# %%
with pd.plotting.plot_params.use('x_compat', True):
    df.A.plot(color='r')
    df.B.plot(color='g')
    df.C.plot(color='b')

# %%
# Using Layout and Targeting Multiple Axes
df.plot(subplots=True, layout=(2, 3), figsize=(8, 6), sharex=False);

# %%
df.plot(subplots=True, figsize=(6, 6));

# %%
df.plot(subplots=True, layout=(2, 2), figsize=(8, 6), sharex=False);

# %%
fig, axes = plt.subplots(4, 4, figsize=(6, 6))

plt.subplots_adjust(wspace=0.5, hspace=0.5)

target1 = [axes[0][0], axes[1][1], axes[2][2], axes[3][3]]

target2 = [axes[3][0], axes[2][1], axes[1][2], axes[0][3]]

df.plot(subplots=True, ax=target1, legend=False,
        sharex=False, sharey=False)

df.plot(subplots=True, ax=target2, legend=False,
        sharex=False, sharey=False);

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

plt.subplots_adjust(wspace=0.2, hspace=0.6)

df['A'].plot(ax=axes[0, 0]);
axes[0, 0].set_title('A');

df['B'].plot(ax=axes[0, 1]);
axes[0, 1].set_title('B');

df['C'].plot(ax=axes[1, 0]);
axes[1, 0].set_title('C');

df['D'].plot(ax=axes[1, 1]);
axes[1, 1].set_title('D');

# %%
# Plotting With Error Bars
# Generate the data
ix3 = pd.MultiIndex.from_arrays([
    ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b'],
    ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar']],
    names=['letter', 'word'])

df3 = pd.DataFrame({'data1': [3, 2, 4, 3, 2, 4, 3, 2],
                              'data2': [6, 5, 7, 5, 4, 5, 6, 5]}, index=ix3)

# Group by index labels and take the means and standard deviations
# for each group

gp3 = df3.groupby(['letter', 'word'])
means = gp3.mean()
errors = gp3.std()
means
# Out:
#              data1  data2
# letter word
# a      bar     3.5    6.0
#        foo     2.5    5.5
# b      bar     2.5    5.5
#        foo     3.0    4.5

# %%
errors
# Out:
#                 data1     data2
# letter word
# a      bar   0.707107  1.414214
#        foo   0.707107  0.707107
# b      bar   0.707107  0.707107
#        foo   1.414214  0.707107

# %%
# Plot
means.plot.bar(yerr=errors, capsize=4);

# %%
# Plotting Tables
fig, ax = plt.subplots(1, 1)
df = pd.DataFrame(np.random.rand(5, 3), columns=['a', 'b', 'c'])
ax.get_xaxis().set_visible(False)   # Hide Ticks
df.plot(table=True, ax=ax);
# 因为这里要hide tricks，所以要引入ax进行调整

# %%
fig, ax = plt.subplots(1, 1)

ax.get_xaxis().set_visible(False)   # Hide Ticks

df.plot(table=np.round(df.T, 2), ax=ax);

# %%
from pandas.plotting import table

fig, ax = plt.subplots(1, 1)

table(ax, np.round(df.describe(), 2),
      loc='upper right', colWidths=[0.2, 0.2, 0.2])

df.plot(ax=ax, ylim=(0, 2), legend=None);

# %%
# Colormaps
# A potential issue when plotting a large number of columns is 
# that it can be difficult to distinguish some series due to repetition in the default colors. 
# To remedy this, DataFrame plotting supports the use of the colormap argument, 
# which accepts either a Matplotlib colormap or a string that is a name of a colormap registered with Matplotlib. 
# A visualization of the default matplotlib colormaps is available here.
# https://matplotlib.org/examples/color/colormaps_reference.html

df = pd.DataFrame(np.random.randn(1000, 10), index=ts.index)

df = df.cumsum()

df.plot(colormap='cubehelix');

# %%
# Colormaps can also be used other plot types, like bar charts:
dd = pd.DataFrame(np.random.randn(10, 10)).applymap(abs)
dd = dd.cumsum()
dd.plot.bar(colormap='Greens');

# %%
# Parallel coordinates charts:
plt.figure()
parallel_coordinates(data, 'species', colormap='gist_rainbow');

# %%
andrews_curves(data, 'species', colormap='winter');

# %%
# Plotting directly with matplotlib
price = pd.Series(np.random.randn(150).cumsum(),
                  index=pd.date_range('2000-1-1', periods=150, freq='B'))

ma = price.rolling(20).mean()
mstd = price.rolling(20).std()
plt.figure()
plt.plot(price.index, price, 'k')
plt.plot(ma.index, ma, 'b')
plt.fill_between(mstd.index, ma - 2 * mstd, ma + 2 * mstd,
                 color='b', alpha=0.2);
